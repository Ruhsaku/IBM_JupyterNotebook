# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
# - List popular languages for Data Science
# - List commonly used libraries for Data Science
# - Evaluate arithmetic expressions
# - Transform minutes to hours

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. SQL
# 3. R
# 4. Scala
# 5. Julia

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. NumPy
# 2. Pandas
# 3. Matplotlib
# 4. SciPy

# %% [markdown]
# |Data Science Tools|
# |---|
# |RStudio|
# |Apache Spark|
# |Apache Hadoop|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This's a simple arithmetic expression to multiply then add integers
print((3*4)+5)
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing 60
minutes = 200
hours = minutes / 60
print(f"200 minutes are {hours} in hours!")
# Out:
# 200 minutes are 3.3333333333333335 in hours!

# %% [markdown]
# ## Author
# Stanislav Mitev
#
# [GitHub Link](https://github.com/Ruhsaku/First_IBM_JupyterNotebook.git)
